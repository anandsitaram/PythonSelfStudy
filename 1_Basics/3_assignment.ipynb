# %%
a=8
b=a
print('value of a:',a)
print('value of b:',b)
a=9
print('value of a:',a)
print('value of b:',b)
a='Anand'
b=True
print('value of a:',a)
print('value of b:',b)
# Out:
# value of a: 8
# value of b: 8
# value of a: 9
# value of b: 8
# value of a: Anand
# value of b: True
