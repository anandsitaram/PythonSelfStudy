# %%
from traceback import print_tb

print("To print any value in console")
# Out:
# To print any value in console

# %%
a=6
b=7.8
c="Test"
print(a)
print(b)
print(c)
# Out:
# 6
# 7.8
# Test

# %%
print("type() will return the data type of variable")
a=6
b=7.8
c="Test"
print(type(a))
print(type(b))
print(type(c))
# Out:
# type() will return the data type of variable
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
# Comment

# %%
#Multiple variable assignment
i,j,k=False,98,"Value"
print(i,j,k)
# Out:
# False 98 Value

# %%
#concatenate
u=90
l="name"
print("Value of u is ",u,"and ",l,"is Virat")
# Out:
# Value of u is  90 and  name is Virat

# %%
## format()
val=90
text="Decimal value is"
print("{} {}".format(text,val))
# Out:
# Decimal value is 90
