# %%
print('''
Generator expressions similar to list co but creates iterable generator object that produces values on demand.This is known as  lazy evaluation
uses parentheses
''')
# Out:
# Generator expressions similar to list co but creates iterable generator object that produces values on demand.This is known as  lazy evaluation

# %%
numbers=[10,5,8,9,3,12,4,1]

for value in (x**2 for x in numbers):
    print(value)
squareOfNumbers=(x**2 for x in numbers)
print(squareOfNumbers) #This is not list
# Out:
# 100
# 25
# 64
# 81
# 9
# 144
# 16
# 1
# <generator object <genexpr> at 0x000002B9A5020380>
